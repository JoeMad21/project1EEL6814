# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import random 
import time
import statistics
import pandas as pd 
import pickle

import matplotlib.pyplot as plt 

from keras.models import Sequential  
from keras.callbacks import EarlyStopping
from keras.backend import clear_session

from keras.layers import Dense, Dropout, Activation, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras import utils
from tensorflow.keras.optimizers import SGD

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# # Load Data, View, and Format

# %%
data_train = np.load('kmnist-train-imgs.npz')
labels_train = np.load('kmnist-train-labels.npz')
data_test = np.load('kmnist-test-imgs.npz')
labels_test = np.load('kmnist-test-labels.npz')

# %%
k_train_samples = data_train['arr_0']
k_train_labels = labels_train['arr_0']
k_test_samples = data_test['arr_0']
k_test_labels = labels_test['arr_0']

# %%
for i in range(9):
    plt.subplot(3,3,i+1)
    num = random.randint(0, len(k_train_samples))
    plt.imshow(k_train_samples[num], cmap='gray', interpolation='none')
    plt.title("Class {}".format(k_train_labels[num]))
    
plt.tight_layout()

# %%
X_train = k_train_samples.reshape(60000, 784) 
X_test = k_test_samples.reshape(10000, 784)   

X_train = X_train.astype('float32')   
X_test = X_test.astype('float32')

X_train /= 255                        
X_test /= 255

X_train = X_train.reshape((X_train.shape[0], 28, 28, 1))
X_test = X_test.reshape((X_test.shape[0], 28, 28, 1))

print("Training matrix shape", X_train.shape)
print("Testing matrix shape", X_test.shape)
# Out:
# Training matrix shape (60000, 28, 28, 1)
# Testing matrix shape (10000, 28, 28, 1)

# %%
no_classes = 10

Y_train = utils.to_categorical(k_train_labels, no_classes)
Y_test = utils.to_categorical(k_test_labels, no_classes)

# %% [markdown]
# # Create Hyperparameter Distributions

# %%
# Hyperparameters

#layer_widths = np.random.randint(1,100,20)
#layer_heights = np.random.randint(1,10,20)
#learning_rates = np.clip(np.random.exponential(scale=1,size=20),0,1)
#momentums = np.clip(np.random.exponential(scale=1,size=20),0,1)
#optimizer_choice = np.zeros(20)
#for i in range(optimizer_choice.shape[0]):
   # optimizer_choice[i] = random.randint(0, 1)
#print(optimizer_choice)
#trial = 0

# %% [raw]
# #clear_session()
# #models = []
# #for lw in layer_widths:
#         model = Sequential()
#         model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', input_shape=(28,28,1)))
#         model.add(MaxPooling2D((2,2)))
#         model.add(Flatten())
#         for lh in layer_heights:
#             model.add(Dense(lw, activation='relu', kernel_initializer='he_uniform'))
#         model.add(Dense(10, activation='softmax'))
#         model.summary()
#         models.append(model)

# %% [raw]
# for model, lr, m in zip(models, learning_rates, momentums):
#             opt = SGD(learning_rate=lr, momentum=m)
#             model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [raw]
# np.random.seed(0)
# callback = EarlyStopping(monitor='loss', patience=2, min_delta=0.01)
# histories = []
# for model in models:
#     idx = np.random.choice(X_train.shape[0], 5000, replace=True)
#     histories.append( model.fit(X_train[idx], Y_train[idx],
#               batch_size=128, epochs=20,
#               verbose=0)) #callbacks=[callback]))

# %% [raw]
# callback = EarlyStopping(monitor='loss', patience=2, min_delta=0.1)
# histories = []
# for model in models:
#     #idx = np.random.choice(X_train.shape[0], 5000, replace=True)
#     histories.append( model.fit(X_train, Y_train,
#               batch_size=128, epochs=10,
#               verbose=1,callbacks=[callback]))

# %% [raw]
# temp = np.random.choice(np.array([0.0001, 0.001, 0.01, 0.1, 1]), size=num_tries_per_trial, replace=True)
# print(temp)
# print(np.unique(temp))

# %%
t0 = time.time()
best_models = []
best_histories = []
best_accuracies = []
best_loss = []
best_lrs = []
best_ms = []
best_widths = []
best_heights = []
best_batch_sizes = []
best_conv_heights = []
best_conv_filters = []
best_scores = []

num_tries_per_trial = 3
num_trials = 20

for trial in range(1,1+num_trials): 
    t0_trial = time.time()
    
    # Hyperparameters
    layer_widths = np.random.randint(5,51,num_tries_per_trial)
    layer_heights = np.random.randint(1,4,num_tries_per_trial)
    learning_rates = np.random.choice(np.array([0.0001, 0.001, 0.01, 0.1, 1]), size=num_tries_per_trial, replace=True)#np.random.randint(1,1000,num_tries_per_trial)/1000 #np.clip(np.random.exponential(scale=1,size=num_tries_per_trial),0,1)
    momentums = np.random.randint(1,10,num_tries_per_trial)/10 #np.clip(np.random.exponential(scale=1,size=num_tries_per_trial),0,1)
    batch_sizes = np.random.choice(np.array([16, 32, 64, 128, 256]), size=num_tries_per_trial, replace=True)
    conv_heights = np.random.randint(1,4,num_tries_per_trial)
    number_filters = np.random.choice(np.array([16, 32, 64, 128, 256]), size=num_tries_per_trial, replace=True)
    
    # Model Construction
    clear_session()
    models = []
    count = 0
    for lw, lh, ch, nf in zip(layer_widths, layer_heights, conv_heights, number_filters):
            model = Sequential()
            for i in range(ch):
                model.add(Conv2D(nf,(3,3), activation='relu', kernel_initializer='he_uniform', input_shape=(28,28,1)))
                model.add(MaxPooling2D((2,2)))
            model.add(Flatten())
            for i in range(lh):
                model.add(Dense(lw, activation='relu', kernel_initializer='he_uniform'))
            model.add(Dense(10, activation='softmax'))
            #model.summary()
            models.append(model)

    # Model Compilation
    for model, lr, m in zip(models, learning_rates, momentums):
        opt = SGD(learning_rate=lr, momentum=m)
        model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

    # Model Training
    callback = EarlyStopping(monitor='loss', patience=1, min_delta=0.5)
    histories = []
    for model, bat_size in zip(models,batch_sizes):
        histories.append( model.fit(X_train, Y_train,
                  batch_size=bat_size, epochs=5,
                  verbose=1,callbacks=[callback]))

    # Identify best model from trial
    find_best_model_in_trial = []
    for history in histories:
        find_best_model_in_trial.append(history.history['loss'][-1])

    index = np.nanargmin(find_best_model_in_trial)
    best_models.append(models[index])
    best_loss.append(histories[index].history['loss'][-1])
    best_histories.append(histories[index])
    best_accuracies.append(histories[index].history['accuracy'][-1])
    best_lrs.append(learning_rates[index])
    best_ms.append(momentums[index])
    best_widths.append(layer_widths[index])
    best_heights.append(layer_heights[index])
    best_batch_sizes.append(batch_sizes[index])
    best_conv_heights.append(conv_heights[index])
    best_conv_filters.append(number_filters[index])
    best_scores.append(models[index].evaluate(X_test, Y_test))

    print("Trial: " + str(trial))
    print("Chosen Model: " + str(index))
    print("Loss: " + str(find_best_model_in_trial[index]))
    print("Training Accuracy: " + str(histories[index].history['accuracy'][-1]))
    print('Test Accuracy: ', best_scores[trial-1][-1])
    print("Learning Rate: " + str(learning_rates[index]))
    print("Momentum: " + str(momentums[index]))
    print("Layer Width: " + str(layer_widths[index]))
    print("Layer Height: " + str(layer_heights[index]))
    print("Batch Size: " + str(batch_sizes[index]))
    print("Convolutional Layer Height: " + str(conv_heights[index]))
    print("Convolutional Layer Filters: " + str(number_filters[index]))
    print()
    t1_trial = time.time()
    print("Trial Time: " + str(t1_trial-t0_trial))
t1 = time.time()
# Out:
# Epoch 1/5
# 469/469 [==============================] - 6s 12ms/step - loss: 1.5321 - accuracy: 0.4093
# Epoch 2/5
# 469/469 [==============================] - 6s 12ms/step - loss: 1.0198 - accuracy: 0.6329
# Epoch 3/5
# 469/469 [==============================] - 5s 12ms/step - loss: 0.7379 - accuracy: 0.7716
# Epoch 1/5
# 3750/3750 [==============================] - 12s 3ms/step - loss: 0.3939 - accuracy: 0.8794
# Epoch 2/5
# 3750/3750 [==============================] - 11s 3ms/step - loss: 0.2019 - accuracy: 0.9390
# Epoch 1/5
# 938/938 [==============================] - 24s 25ms/step - loss: 1.0946 - accuracy: 0.6855
# Epoch 2/5
# 938/938 [==============================] - 23s 24ms/step - loss: 0.5967 - accuracy: 0.8297
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4349 - accuracy: 0.8722
# Trial: 1
# Chosen Model: 1
# Loss: 0.2018817663192749
# Training Accuracy: 0.9389500021934509
# Test Accuracy:  [0.43489131331443787, 0.8722000122070312]
# Learning Rate: 0.01
# Momentum: 0.2
# Layer Width: 49
# Layer Height: 1
# Batch Size: 16
# Convolutional Layer Height: 1
# Convolutional Layer Filters: 32
#
# Trial Time: 87.14621806144714
# Epoch 1/5
# 1875/1875 [==============================] - 45s 24ms/step - loss: 1.6830 - accuracy: 0.4744
# Epoch 2/5
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.9904 - accuracy: 0.7203
# Epoch 3/5
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.7483 - accuracy: 0.7817
# Epoch 1/5
# 235/235 [==============================] - 6s 24ms/step - loss: 0.7417 - accuracy: 0.7804
# Epoch 2/5
# 235/235 [==============================] - 6s 24ms/step - loss: 0.4143 - accuracy: 0.8776
# Epoch 1/5
# 469/469 [==============================] - 21s 44ms/step - loss: 2.4402 - accuracy: 0.1131
# Epoch 2/5
# 469/469 [==============================] - 21s 44ms/step - loss: 2.2935 - accuracy: 0.1347
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7647 - accuracy: 0.7621
# Trial: 2
# Chosen Model: 1
# Loss: 0.4143127501010895
# Training Accuracy: 0.8776000142097473
# Test Accuracy:  [0.7646695971488953, 0.7620999813079834]
# Learning Rate: 0.01
# Momentum: 0.5
# Layer Width: 43
# Layer Height: 2
# Batch Size: 256
# Convolutional Layer Height: 1
# Convolutional Layer Filters: 32
#
# Trial Time: 189.03522372245789
# Epoch 1/5
# 938/938 [==============================] - 25s 26ms/step - loss: 2.4073 - accuracy: 0.1007
# Epoch 2/5
# 938/938 [==============================] - 24s 25ms/step - loss: 2.3145 - accuracy: 0.1029
# Epoch 1/5
# 3750/3750 [==============================] - 31s 8ms/step - loss: 0.5624 - accuracy: 0.8307
# Epoch 2/5
# 3750/3750 [==============================] - 30s 8ms/step - loss: 0.2965 - accuracy: 0.9123
# Epoch 1/5
# 1875/1875 [==============================] - 44s 23ms/step - loss: 2.1594 - accuracy: 0.1941
# Epoch 2/5
# 1875/1875 [==============================] - 44s 23ms/step - loss: 1.9704 - accuracy: 0.2500
# 313/313 [==============================] - 2s 5ms/step - loss: 0.5564 - accuracy: 0.8350
# Trial: 3
# Chosen Model: 1
# Loss: 0.2964920997619629
# Training Accuracy: 0.9122999906539917
# Test Accuracy:  [0.5564072728157043, 0.8349999785423279]
# Learning Rate: 0.001
# Momentum: 0.5
# Layer Width: 27
# Layer Height: 2
# Batch Size: 16
# Convolutional Layer Height: 1
# Convolutional Layer Filters: 128
#
# Trial Time: 200.07841396331787
# Epoch 1/5
# 469/469 [==============================] - 43s 90ms/step - loss: 2.1568 - accuracy: 0.2055
# Epoch 2/5
# 469/469 [==============================] - 42s 91ms/step - loss: 1.9578 - accuracy: 0.3041
# Epoch 1/5
# 938/938 [==============================] - 7s 8ms/step - loss: 0.3526 - accuracy: 0.8913
# Epoch 2/5
# 938/938 [==============================] - 7s 8ms/step - loss: 0.1400 - accuracy: 0.9581
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 1.4396 - accuracy: 0.4658
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3403 - accuracy: 0.8993
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2133 - accuracy: 0.9370
# 313/313 [==============================] - 1s 1ms/step - loss: 0.4209 - accuracy: 0.8905
# Trial: 4
# Chosen Model: 1
# Loss: 0.140022411942482
# Training Accuracy: 0.958050012588501
# Test Accuracy:  [0.4209364354610443, 0.890500009059906]
# Learning Rate: 0.1
# Momentum: 0.7
# Layer Width: 33
# Layer Height: 1
# Batch Size: 64
# Convolutional Layer Height: 1
# Convolutional Layer Filters: 32
#
# Trial Time: 122.64569115638733
# Epoch 1/5
# 469/469 [==============================] - 6s 13ms/step - loss: 1.5612 - accuracy: 0.5203
# Epoch 2/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.8635 - accuracy: 0.7560
# Epoch 3/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.6710 - accuracy: 0.8081
# Epoch 1/5
# 1875/1875 [==============================] - 106s 56ms/step - loss: 1.2213 - accuracy: 0.5877
# Epoch 2/5
# 1875/1875 [==============================] - 102s 54ms/step - loss: 0.6037 - accuracy: 0.8205
# Epoch 3/5
# 1875/1875 [==============================] - 100s 54ms/step - loss: 0.4128 - accuracy: 0.8793
# Epoch 1/5
# 938/938 [==============================] - 7s 7ms/step - loss: 2.1950 - accuracy: 0.1731
# Epoch 2/5
# 938/938 [==============================] - 6s 7ms/step - loss: 1.8201 - accuracy: 0.4144
# 313/313 [==============================] - 5s 16ms/step - loss: 0.7381 - accuracy: 0.7758
# Trial: 5
# Chosen Model: 1
# Loss: 0.4127519726753235
# Training Accuracy: 0.8792833089828491
# Test Accuracy:  [0.7381150126457214, 0.7757999897003174]
# Learning Rate: 0.001
# Momentum: 0.6
# Layer Width: 6
# Layer Height: 1
# Batch Size: 32
# Convolutional Layer Height: 2
# Convolutional Layer Filters: 256
#
# Trial Time: 344.25976753234863
# Epoch 1/5
# 469/469 [==============================] - 11s 23ms/step - loss: 1.0355 - accuracy: 0.6722
# Epoch 2/5
# 469/469 [==============================] - 10s 22ms/step - loss: 0.5622 - accuracy: 0.8296
# Epoch 1/5
# 938/938 [==============================] - 105s 111ms/step - loss: 2.0592 - accuracy: 0.2844
# Epoch 2/5
# 938/938 [==============================] - 105s 112ms/step - loss: 1.5463 - accuracy: 0.5198
# Epoch 3/5
# 938/938 [==============================] - 104s 111ms/step - loss: 1.1296 - accuracy: 0.6601
# Epoch 1/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 2.0507 - accuracy: 0.2931
# Epoch 2/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 1.6762 - accuracy: 0.4956
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8962 - accuracy: 0.7219
# Trial: 6
# Chosen Model: 0
# Loss: 0.5621627569198608
# Training Accuracy: 0.8295666575431824
# Test Accuracy:  [0.8961507081985474, 0.7218999862670898]
# Learning Rate: 0.01
# Momentum: 0.5
# Layer Width: 14
# Layer Height: 1
# Batch Size: 128
# Convolutional Layer Height: 2
# Convolutional Layer Filters: 32
#
# Trial Time: 360.5200366973877
# Epoch 1/5
# 235/235 [==============================] - 10s 40ms/step - loss: nan - accuracy: 0.1001
# Epoch 2/5
# 235/235 [==============================] - 9s 40ms/step - loss: nan - accuracy: 0.1000
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.6896 - accuracy: 0.7693
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3274 - accuracy: 0.8971
# Epoch 1/5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.9532 - accuracy: 0.6781
# Epoch 2/5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.4825 - accuracy: 0.8469
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6024 - accuracy: 0.8222
# Trial: 7
# Chosen Model: 1
# Loss: 0.3274460434913635
# Training Accuracy: 0.8971333503723145
# Test Accuracy:  [0.6024214625358582, 0.8222000002861023]
# Learning Rate: 0.1
# Momentum: 0.1
# Layer Width: 20
# Layer Height: 1
# Batch Size: 32
# Convolutional Layer Height: 3
# Convolutional Layer Filters: 16
#
# Trial Time: 49.416528940200806
# Epoch 1/5
# 235/235 [==============================] - 10s 42ms/step - loss: 1.8496 - accuracy: 0.3528
# Epoch 2/5
# 235/235 [==============================] - 10s 42ms/step - loss: 0.8971 - accuracy: 0.7283
# Epoch 3/5
# 235/235 [==============================] - 10s 41ms/step - loss: 0.6431 - accuracy: 0.8089
# Epoch 1/5
# 938/938 [==============================] - 13s 13ms/step - loss: 2.0163 - accuracy: 0.2469
# Epoch 2/5
# 938/938 [==============================] - 12s 13ms/step - loss: 1.6867 - accuracy: 0.3976
# Epoch 1/5
# 469/469 [==============================] - 25s 52ms/step - loss: 2.4063 - accuracy: 0.1002
# Epoch 2/5
# 469/469 [==============================] - 25s 52ms/step - loss: 2.3124 - accuracy: 0.1021
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0113 - accuracy: 0.6889
# Trial: 8
# Chosen Model: 0
# Loss: 0.6430789232254028
# Training Accuracy: 0.8089333176612854
# Test Accuracy:  [1.0113441944122314, 0.6888999938964844]
# Learning Rate: 0.001
# Momentum: 0.9
# Layer Width: 30
# Layer Height: 2
# Batch Size: 256
# Convolutional Layer Height: 2
# Convolutional Layer Filters: 32
#
# Trial Time: 105.40647029876709
# Epoch 1/5
# 938/938 [==============================] - 22s 23ms/step - loss: 0.6452 - accuracy: 0.8062
# Epoch 2/5
# 938/938 [==============================] - 22s 23ms/step - loss: 0.4055 - accuracy: 0.8984
# Epoch 1/5
# 938/938 [==============================] - 26s 28ms/step - loss: 0.7075 - accuracy: 0.7898
# Epoch 2/5
# 938/938 [==============================] - 26s 28ms/step - loss: 0.3952 - accuracy: 0.8845
# Epoch 1/5
# 938/938 [==============================] - 23s 24ms/step - loss: 2.1699 - accuracy: 0.1971
# Epoch 2/5
# 938/938 [==============================] - 23s 24ms/step - loss: 1.9327 - accuracy: 0.2819
# 313/313 [==============================] - 2s 5ms/step - loss: 0.7340 - accuracy: 0.7691
# Trial: 9
# Chosen Model: 1
# Loss: 0.3952218294143677
# Training Accuracy: 0.8845499753952026
# Test Accuracy:  [0.733985424041748, 0.76910001039505]
# Learning Rate: 0.001
# Momentum: 0.2
# Layer Width: 41
# Layer Height: 3
# Batch Size: 64
# Convolutional Layer Height: 1
# Convolutional Layer Filters: 128
#
# Trial Time: 144.30003213882446
# Epoch 1/5
# 235/235 [==============================] - 11s 44ms/step - loss: 2.5030 - accuracy: 0.0827
# Epoch 2/5
# 235/235 [==============================] - 10s 44ms/step - loss: 2.3401 - accuracy: 0.0915
# Epoch 1/5
# 3750/3750 [==============================] - 7s 2ms/step - loss: 1.2874 - accuracy: 0.5340
# Epoch 2/5
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.6757 - accuracy: 0.7941
# Epoch 3/5
# 3750/3750 [==============================] - 6s 2ms/step - loss: 0.4658 - accuracy: 0.8641
# Epoch 1/5
# 469/469 [==============================] - 6s 12ms/step - loss: 1.6089 - accuracy: 0.4485
# Epoch 2/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.9692 - accuracy: 0.6825
# Epoch 3/5
# 469/469 [==============================] - 6s 12ms/step - loss: 0.8142 - accuracy: 0.7360
# 313/313 [==============================] - 0s 1ms/step - loss: 0.9458 - accuracy: 0.7471
# Trial: 10
# Chosen Model: 1
# Loss: 0.465785950422287
# Training Accuracy: 0.8640666604042053
# Test Accuracy:  [0.9458010792732239, 0.7470999956130981]
# Learning Rate: 0.01
# Momentum: 0.6
# Layer Width: 6
# Layer Height: 3
# Batch Size: 16
# Convolutional Layer Height: 1
# Convolutional Layer Filters: 16
#
# Trial Time: 58.88945293426514
# Epoch 1/5
# 3750/3750 [==============================] - 24s 6ms/step - loss: 0.9906 - accuracy: 0.6837
# Epoch 2/5
# 3750/3750 [==============================] - 24s 7ms/step - loss: 0.4711 - accuracy: 0.8580
# Epoch 3/5
# 3750/3750 [==============================] - 24s 6ms/step - loss: 0.3385 - accuracy: 0.8990
# Epoch 1/5
# 3750/3750 [==============================] - 14s 4ms/step - loss: 1016.2856 - accuracy: 0.1017
# Epoch 2/5
# 3750/3750 [==============================] - 14s 4ms/step - loss: 2.4490 - accuracy: 0.0997
# Epoch 3/5
# 3750/3750 [==============================] - 13s 4ms/step - loss: 2.4557 - accuracy: 0.1008
# Epoch 1/5
# 938/938 [==============================] - 46s 49ms/step - loss: 0.5599 - accuracy: 0.8157
# Epoch 2/5
# 938/938 [==============================] - 47s 50ms/step - loss: 0.1740 - accuracy: 0.9467
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3834 - accuracy: 0.8829
# Trial: 11
# Chosen Model: 2
# Loss: 0.17396479845046997
# Training Accuracy: 0.9466833472251892
# Test Accuracy:  [0.383426308631897, 0.8828999996185303]
# Learning Rate: 0.01
# Momentum: 0.9
# Layer Width: 24
# Layer Height: 2
# Batch Size: 64
# Convolutional Layer Height: 3
# Convolutional Layer Filters: 128
#
# Trial Time: 209.02359056472778
# Epoch 1/5
# 469/469 [==============================] - 7s 15ms/step - loss: 1951073042432.0000 - accuracy: 0.0986
# Epoch 2/5
# 469/469 [==============================] - 7s 15ms/step - loss: 2.3054 - accuracy: 0.1000
# Epoch 3/5
# 469/469 [==============================] - 6s 14ms/step - loss: 2.3054 - accuracy: 0.0986
# Epoch 1/5
# 469/469 [==============================] - 7s 14ms/step - loss: 0.4131 - accuracy: 0.8691
# Epoch 2/5
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1372 - accuracy: 0.9586
# Epoch 1/5
# 235/235 [==============================] - 11s 44ms/step - loss: 2.2291 - accuracy: 0.1958
# Epoch 2/5
# 235/235 [==============================] - 10s 42ms/step - loss: 2.0743 - accuracy: 0.2566
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3313 - accuracy: 0.9073
# Trial: 12
# Chosen Model: 1
# Loss: 0.13715898990631104
# Training Accuracy: 0.9585833549499512
# Test Accuracy:  [0.3313342332839966, 0.9072999954223633]
# Learning Rate: 0.1
# Momentum: 0.7
# Layer Width: 50
# Layer Height: 3
# Batch Size: 128
# Convolutional Layer Height: 1
# Convolutional Layer Filters: 32
#
# Trial Time: 56.00532126426697
# Epoch 1/5
# 1875/1875 [==============================] - 107s 57ms/step - loss: 2.3199 - accuracy: 0.0986
# Epoch 2/5
# 1875/1875 [==============================] - 107s 57ms/step - loss: 2.3087 - accuracy: 0.0999
# Epoch 1/5
# 3750/3750 [==============================] - 55s 15ms/step - loss: 2.0368 - accuracy: 0.2926
# Epoch 2/5
# 3750/3750 [==============================] - 55s 15ms/step - loss: 1.7599 - accuracy: 0.4048
# Epoch 1/5
# 1875/1875 [==============================] - 50s 26ms/step - loss: 1.5845 - accuracy: 0.5019
# Epoch 2/5
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.8233 - accuracy: 0.7582
# Epoch 3/5
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.6288 - accuracy: 0.8135
# 313/313 [==============================] - 3s 8ms/step - loss: 0.9796 - accuracy: 0.6874
# Trial: 13
# Chosen Model: 2
# Loss: 0.6288301348686218
# Training Accuracy: 0.8134833574295044
# Test Accuracy:  [0.9795657992362976, 0.6873999834060669]
# Learning Rate: 0.0001
# Momentum: 0.7
# Layer Width: 38
# Layer Height: 3
# Batch Size: 32
# Convolutional Layer Height: 2
# Convolutional Layer Filters: 128
#
# Trial Time: 477.7331874370575
# Epoch 1/5
# 235/235 [==============================] - 50s 210ms/step - loss: 1.7570 - accuracy: 0.4643
# Epoch 2/5
# 235/235 [==============================] - 50s 211ms/step - loss: 1.2472 - accuracy: 0.6759
# Epoch 3/5
# 235/235 [==============================] - 49s 209ms/step - loss: 1.0361 - accuracy: 0.7270
# Epoch 1/5
# 235/235 [==============================] - 11s 45ms/step - loss: 1.6753 - accuracy: 0.3836
# Epoch 2/5
# 235/235 [==============================] - 11s 46ms/step - loss: 0.6436 - accuracy: 0.7921
# Epoch 3/5
# 235/235 [==============================] - 11s 45ms/step - loss: 0.3967 - accuracy: 0.8762
# Epoch 1/5
# 3750/3750 [==============================] - 59s 16ms/step - loss: 0.5129 - accuracy: 0.8419
# Epoch 2/5
# 3750/3750 [==============================] - 59s 16ms/step - loss: 0.2068 - accuracy: 0.9389
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4502 - accuracy: 0.8595
# Trial: 14
# Chosen Model: 2
# Loss: 0.20682856440544128
# Training Accuracy: 0.9388999938964844
# Test Accuracy:  [0.4502158761024475, 0.859499990940094]
# Learning Rate: 0.001
# Momentum: 0.8
# Layer Width: 22
# Layer Height: 2
# Batch Size: 16
# Convolutional Layer Height: 2
# Convolutional Layer Filters: 128
#
# Trial Time: 301.7687888145447
# Epoch 1/5
# 3750/3750 [==============================] - 150s 40ms/step - loss: 0.6957 - accuracy: 0.7642
# Epoch 2/5
# 3750/3750 [==============================] - 151s 40ms/step - loss: 0.1667 - accuracy: 0.9498
# Epoch 3/5
# 3750/3750 [==============================] - 148s 39ms/step - loss: 0.0968 - accuracy: 0.9697
# Epoch 1/5
# 3750/3750 [==============================] - 34s 9ms/step - loss: 1.5653 - accuracy: 0.4949
# Epoch 2/5
# 3750/3750 [==============================] - 34s 9ms/step - loss: 2.1198 - accuracy: 0.2053
# Epoch 1/5
# 469/469 [==============================] - 126s 267ms/step - loss: 9.0855 - accuracy: 0.0994
# Epoch 2/5
# 469/469 [==============================] - 127s 271ms/step - loss: 2.3061 - accuracy: 0.1009
# Epoch 3/5
# 469/469 [==============================] - 127s 272ms/step - loss: 2.3060 - accuracy: 0.1007
# 313/313 [==============================] - 8s 25ms/step - loss: 0.3008 - accuracy: 0.9151
# Trial: 15
# Chosen Model: 0
# Loss: 0.096806101500988
# Training Accuracy: 0.9696666598320007
# Test Accuracy:  [0.30078068375587463, 0.9150999784469604]
# Learning Rate: 0.01
# Momentum: 0.6
# Layer Width: 24
# Layer Height: 2
# Batch Size: 16
# Convolutional Layer Height: 3
# Convolutional Layer Filters: 256
#
# Trial Time: 904.7272064685822
# Epoch 1/5
# 3750/3750 [==============================] - 12s 3ms/step - loss: 0.8954 - accuracy: 0.6956
# Epoch 2/5
# 3750/3750 [==============================] - 12s 3ms/step - loss: 0.4401 - accuracy: 0.8591
# Epoch 1/5
# 469/469 [==============================] - 52s 109ms/step - loss: 1.2426 - accuracy: 0.5748
# Epoch 2/5
# 469/469 [==============================] - 51s 110ms/step - loss: 0.7197 - accuracy: 0.7685
# Epoch 3/5
# 469/469 [==============================] - 52s 110ms/step - loss: 0.5694 - accuracy: 0.8247
# Epoch 1/5
# 235/235 [==============================] - 13s 53ms/step - loss: 1.3262 - accuracy: 0.4900
# Epoch 2/5
# 235/235 [==============================] - 12s 53ms/step - loss: 0.6106 - accuracy: 0.8018
# Epoch 3/5
# 235/235 [==============================] - 12s 53ms/step - loss: 0.4685 - accuracy: 0.8535
# 313/313 [==============================] - 1s 1ms/step - loss: 0.7242 - accuracy: 0.7714
# Trial: 16
# Chosen Model: 0
# Loss: 0.4400573670864105
# Training Accuracy: 0.859083354473114
# Test Accuracy:  [0.7241860032081604, 0.771399974822998]
# Learning Rate: 0.01
# Momentum: 0.6
# Layer Width: 30
# Layer Height: 3
# Batch Size: 16
# Convolutional Layer Height: 3
# Convolutional Layer Filters: 16
#
# Trial Time: 217.74034905433655
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3820 - accuracy: 0.8819
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1563 - accuracy: 0.9535
# Epoch 1/5
# 1875/1875 [==============================] - 52s 27ms/step - loss: 0.6706 - accuracy: 0.7762
# Epoch 2/5
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.1829 - accuracy: 0.9454
# Epoch 1/5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.3249 - accuracy: 0.8991
# Epoch 2/5
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.1010 - accuracy: 0.9699
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2513 - accuracy: 0.9295
# Trial: 17
# Chosen Model: 2
# Loss: 0.1010039821267128
# Training Accuracy: 0.9698500037193298
# Test Accuracy:  [0.25132155418395996, 0.9294999837875366]
# Learning Rate: 0.1
# Momentum: 0.1
# Layer Width: 46
# Layer Height: 3
# Batch Size: 32
# Convolutional Layer Height: 2
# Convolutional Layer Filters: 64
#
# Trial Time: 166.5222508907318
# Epoch 1/5
# 938/938 [==============================] - 47s 49ms/step - loss: 1.3887 - accuracy: 0.5521
# Epoch 2/5
# 938/938 [==============================] - 46s 49ms/step - loss: 0.7109 - accuracy: 0.7848
# Epoch 3/5
# 938/938 [==============================] - 46s 49ms/step - loss: 0.5246 - accuracy: 0.8378
# Epoch 1/5
# 938/938 [==============================] - 23s 25ms/step - loss: 1.4780 - accuracy: 0.5101
# Epoch 2/5
# 938/938 [==============================] - 23s 24ms/step - loss: 0.8392 - accuracy: 0.7290
# Epoch 3/5
# 938/938 [==============================] - 23s 24ms/step - loss: 0.6463 - accuracy: 0.7911
# Epoch 1/5
# 3750/3750 [==============================] - 15s 4ms/step - loss: 1.9282 - accuracy: 0.3854
# Epoch 2/5
# 3750/3750 [==============================] - 14s 4ms/step - loss: 1.2662 - accuracy: 0.6431
# Epoch 3/5
# 3750/3750 [==============================] - 14s 4ms/step - loss: 1.0004 - accuracy: 0.7112
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8962 - accuracy: 0.7215
# Trial: 18
# Chosen Model: 0
# Loss: 0.5245851278305054
# Training Accuracy: 0.8378000259399414
# Test Accuracy:  [0.8961812257766724, 0.7214999794960022]
# Learning Rate: 0.001
# Momentum: 0.6
# Layer Width: 22
# Layer Height: 2
# Batch Size: 64
# Convolutional Layer Height: 3
# Convolutional Layer Filters: 128
#
# Trial Time: 254.3032419681549
# Epoch 1/5
# 938/938 [==============================] - 25s 27ms/step - loss: 1565627574546893635584.0000 - accuracy: 0.1005
# Epoch 2/5
# 938/938 [==============================] - 25s 27ms/step - loss: 2.3145 - accuracy: 0.0996
# Epoch 3/5
# 938/938 [==============================] - 25s 27ms/step - loss: 2.3153 - accuracy: 0.0978
# Epoch 1/5
# 938/938 [==============================] - 8s 8ms/step - loss: 0.5131 - accuracy: 0.8387
# Epoch 2/5
# 938/938 [==============================] - 7s 8ms/step - loss: 0.1937 - accuracy: 0.9422
# Epoch 1/5
# 3750/3750 [==============================] - 15s 4ms/step - loss: 0.6021 - accuracy: 0.8054
# Epoch 2/5
# 3750/3750 [==============================] - 14s 4ms/step - loss: 0.2259 - accuracy: 0.9314
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4258 - accuracy: 0.8752
# Trial: 19
# Chosen Model: 1
# Loss: 0.1936720758676529
# Training Accuracy: 0.9421833157539368
# Test Accuracy:  [0.42577865719795227, 0.8751999735832214]
# Learning Rate: 0.01
# Momentum: 0.9
# Layer Width: 15
# Layer Height: 2
# Batch Size: 64
# Convolutional Layer Height: 1
# Convolutional Layer Filters: 32
#
# Trial Time: 120.57645106315613
# Epoch 1/5
# 3750/3750 [==============================] - 24s 6ms/step - loss: 0.5478 - accuracy: 0.8266
# Epoch 2/5
# 3750/3750 [==============================] - 25s 7ms/step - loss: 0.1898 - accuracy: 0.9428
# Epoch 1/5
# 3750/3750 [==============================] - 11s 3ms/step - loss: 2.3400 - accuracy: 0.1007
# Epoch 2/5
# 3750/3750 [==============================] - 10s 3ms/step - loss: 2.3309 - accuracy: 0.1017
# Epoch 1/5
# 938/938 [==============================] - 109s 116ms/step - loss: 2.0183 - accuracy: 0.2891
# Epoch 2/5
# 938/938 [==============================] - 109s 116ms/step - loss: 1.6895 - accuracy: 0.4396
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3989 - accuracy: 0.8871
# Trial: 20
# Chosen Model: 0
# Loss: 0.1897684931755066
# Training Accuracy: 0.9428333044052124
# Test Accuracy:  [0.398891419172287, 0.8870999813079834]
# Learning Rate: 0.01
# Momentum: 0.4
# Layer Width: 15
# Layer Height: 2
# Batch Size: 16
# Convolutional Layer Height: 2
# Convolutional Layer Filters: 64
#
# Trial Time: 288.28462314605713

# %%
with open('best_models.pkl', 'wb') as f:
    pickle.dump(best_models,f)

with open('best_loss.pkl', 'wb') as f:
    pickle.dump(best_loss,f)
    
with open('best_histories.pkl', 'wb') as f:
    pickle.dump(best_histories,f)
    
with open('best_accuracies.pkl', 'wb') as f:
    pickle.dump(best_accuracies,f)
    
with open('best_lrs.pkl', 'wb') as f:
    pickle.dump(best_lrs,f)
    
with open('best_ms.pkl', 'wb') as f:
    pickle.dump(best_ms,f)
    
with open('best_widths.pkl', 'wb') as f:
    pickle.dump(best_widths,f)

with open('best_heights.pkl', 'wb') as f:
    pickle.dump(best_heights,f)
    
index = np.nanargmin(find_best_model_in_trial)
    best_models.append(models[index])
    best_loss.append(histories[index].history['loss'][-1])
    best_histories.append(histories[index])
    best_accuracies.append(histories[index].history['accuracy'][-1])
    best_lrs.append(learning_rates[index])
    best_ms.append(momentums[index])
    best_widths.append(layer_widths[index])
    best_heights.append(layer_heights[index])
    best_batch_sizes.append(batch_sizes[index])
    best_conv_heights.append(conv_heights[index])
    best_conv_filters.append(number_filters[index])
    best_scores.append(models[index].evaluate(X_test, Y_test))

# %%
#idx = np.nanargmin(best_loss)
#print("Chosen Trial: " + str(idx+1))
#print("Final Loss: " + str(best_loss[idx]))
#print("Final Accuracy: " + str(best_histories[idx].history['accuracy'][-1]))
#print("Final Learning Rate: " + str(best_lrs[idx]))
#print("Final Momentum: " + str(best_ms[idx]))
#print("Layer Width: " + str(best_widths[idx]))
#print("Layer Height: " + str(best_heights[idx]))
#print()
#print("Total Tuning Time: " + str(t1-t0) + "s")
#print()

# %%
# initialize data of lists. 
test_accuracies = []
for score in best_scores:
    test_accuracies.append(score[-1])
data = {'Learning Rate': best_lrs,
        'Momentum:': best_ms,
        'Hidden Layer Width': best_widths,
        'Hidden Layer Height': best_heights,
        'Batch Size': best_batch_sizes,
        'Convolutional Layer Height': best_conv_heights,
        'Convolutional Layer Filters': best_conv_filters,
        'Training Accuracy': best_accuracies, 
        'Testing Accuracy': test_accuracies} 

# Create DataFrame 
df = pd.DataFrame(data) 
  
# Print the output. 
display(df)
display(df.corr())
# Out:
#     Learning Rate  Momentum:  Hidden Layer Width  Hidden Layer Height  \
# 0          0.0100        0.2                  49                    1
# 1          0.0100        0.5                  43                    2
# 2          0.0010        0.5                  27                    2
# 3          0.1000        0.7                  33                    1
# 4          0.0010        0.6                   6                    1
# 5          0.0100        0.5                  14                    1
# 6          0.1000        0.1                  20                    1
# 7          0.0010        0.9                  30                    2
# 8          0.0010        0.2                  41                    3
# 9          0.0100        0.6                   6                    3
# 10         0.0100        0.9                  24                    2
# 11         0.1000        0.7                  50                    3
# 12         0.0001        0.7                  38                    3
# 13         0.0010        0.8                  22                    2
# 14         0.0100        0.6                  24                    2
# 15         0.0100        0.6                  30                    3
# 16         0.1000        0.1                  46                    3
# 17         0.0010        0.6                  22                    2
# 18         0.0100        0.9                  15                    2
# 19         0.0100        0.4                  15                    2
#
#     Batch Size  Convolutional Layer Height  Convolutional Layer Filters  \
# 0           16                           1                           32
# 1          256                           1                           32
# 2           16                           1                          128
# 3           64                           1                           32
# 4           32                           2                          256
# 5          128                           2                           32
# 6           32                           3                           16
# 7          256                           2                           32
# 8           64                           1                          128
# 9           16                           1                           16
# 10          64                           3                          128
# 11         128                           1                           32
# 12          32                           2                          128
# 13          16                           2                          128
# 14          16                           3                          256
# 15          16                           3                           16
# 16          32                           2                           64
# 17          64                           3                          128
# 18          64                           1                           32
# 19          16                           2                           64
#
#     Training Accuracy  Testing Accuracy
# 0            0.938950            0.8722
# 1            0.877600            0.7621
# 2            0.912300            0.8350
# 3            0.958050            0.8905
# 4            0.879283            0.7758
# 5            0.829567            0.7219
# 6            0.897133            0.8222
# 7            0.808933            0.6889
# 8            0.884550            0.7691
# 9            0.864067            0.7471
# 10           0.946683            0.8829
# 11           0.958583            0.9073
# 12           0.813483            0.6874
# 13           0.938900            0.8595
# 14           0.969667            0.9151
# 15           0.859083            0.7714
# 16           0.969850            0.9295
# 17           0.837800            0.7215
# 18           0.942183            0.8752
# 19           0.942833            0.8871
#                              Learning Rate  Momentum:  Hidden Layer Width  \
# Learning Rate                     1.000000  -0.323486            0.351058
# Momentum:                        -0.323486   1.000000           -0.284671
# Hidden Layer Width                0.351058  -0.284671            1.000000
# Hidden Layer Height              -0.044146   0.067885            0.315324
# Batch Size                       -0.017954   0.267989            0.264319
# Convolutional Layer Height       -0.061066   0.042705           -0.292134
# Convolutional Layer Filters      -0.372987   0.119193           -0.230949
# Training Accuracy                 0.461918  -0.125795            0.205435
# Testing Accuracy                  0.499798  -0.140051            0.205144
#
#                              Hidden Layer Height  Batch Size  \
# Learning Rate                          -0.044146   -0.017954
# Momentum:                               0.067885    0.267989
# Hidden Layer Width                      0.315324    0.264319
# Hidden Layer Height                     1.000000   -0.047683
# Batch Size                             -0.047683    1.000000
# Convolutional Layer Height             -0.072509   -0.205731
# Convolutional Layer Filters            -0.063604   -0.321861
# Training Accuracy                      -0.071176   -0.367934
# Testing Accuracy                       -0.076111   -0.379185
#
#                              Convolutional Layer Height  \
# Learning Rate                                 -0.061066
# Momentum:                                      0.042705
# Hidden Layer Width                            -0.292134
# Hidden Layer Height                           -0.072509
# Batch Size                                    -0.205731
# Convolutional Layer Height                     1.000000
# Convolutional Layer Filters                    0.318026
# Training Accuracy                             -0.147284
# Testing Accuracy                              -0.079489
#
#                              Convolutional Layer Filters  Training Accuracy  \
# Learning Rate                                  -0.372987           0.461918
# Momentum:                                       0.119193          -0.125795
# Hidden Layer Width                             -0.230949           0.205435
# Hidden Layer Height                            -0.063604          -0.071176
# Batch Size                                     -0.321861          -0.367934
# Convolutional Layer Height                      0.318026          -0.147284
# Convolutional Layer Filters                     1.000000           0.105663
# Training Accuracy                               0.105663           1.000000
# Testing Accuracy                                0.064882           0.990179
#
#                              Testing Accuracy
# Learning Rate                        0.499798
# Momentum:                           -0.140051
# Hidden Layer Width                   0.205144
# Hidden Layer Height                 -0.076111
# Batch Size                          -0.379185
# Convolutional Layer Height          -0.079489
# Convolutional Layer Filters          0.064882
# Training Accuracy                    0.990179
# Testing Accuracy                     1.000000

# %%
chosen_idx = np.argwhere(np.array(best_accuracies) > 0.80)

ab_lrs = []
for idx in chosen_idx:
    ab_lrs.append(best_lrs[idx[0]])


lrs_unique, lrs_counts = np.unique(ab_lrs, return_counts=True)
lrs_data = dict(zip(lrs_unique, lrs_counts))

lr_x_values = list(lrs_data.keys())
lr_y_values = list(lrs_data.values())
lr_x_values = [str(r) for r in lr_x_values]
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(lr_x_values, lr_y_values, color ='maroon', 
        width = 0.1)

 
plt.xlabel("Learning Rate")
plt.ylabel("# of instances")
plt.title("Learning Rates in Trials")
plt.xticks(lr_x_values,rotation=45)
plt.show()

lr_select = statistics.mode(ab_lrs)

# %%
chosen_idx = np.argwhere(np.array(best_lrs) == lr_select)

ab_ms = []
for idx in chosen_idx:
    ab_ms.append(best_ms[idx[0]])

ms_unique, ms_counts = np.unique(ab_ms, return_counts=True)
ms_data = dict(zip(ms_unique, ms_counts))

m_x_values = list(ms_data.keys())
m_y_values = list(ms_data.values())
m_x_values = [str(r) for r in m_x_values]
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(m_x_values, m_y_values, color ='maroon', 
        width = 0.1)

 
plt.xlabel("Momentum")
plt.ylabel("# of instances")
plt.title("Momentums in Trials")
plt.xticks(m_x_values,rotation=45)
plt.show()

m_select = statistics.mode(ab_ms)
print(m_select)

# %%
chosen_idx = np.argwhere(np.array(best_ms) == m_select)

ab_lhs = []
for idx in chosen_idx:
    ab_lhs.append(best_heights[idx[0]])

lhs_unique, lhs_counts = np.unique(ab_lhs, return_counts=True)
lhs_data = dict(zip(lhs_unique, lhs_counts))

lh_x_values = list(lhs_data.keys())
lh_y_values = list(lhs_data.values())
lh_x_values = [str(r) for r in lh_x_values]
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(lh_x_values, lh_y_values, color ='maroon', 
        width = 0.1)

 
plt.xlabel("Heights")
plt.ylabel("# of instances")
plt.title("Layer Heights in Trials")
plt.xticks(lh_x_values,rotation=45)
plt.show()

lh_mode = statistics.mode(ab_lhs)
print(lh_mode)

# %% [raw]
# if trial == 0:
#     best_models = []
#     best_histories = []
#     best_accuracies = []
#     best_lrs = []
#     best_ms = []
#     best_widths = []
#     best_heights = []
#     trial = 0

# %% [raw]
# find_best_model_in_trial = []
# for history in histories:
#     find_best_model_in_trial.append(history.history['loss'][-1])
#
# index = np.nanargmin(find_best_model_in_trial)
# best_models.append(models[index])
# best_histories.append(histories[index])
# best_accuracies.append(histories[index].history['accuracy'][-1])
# best_lrs.append(learning_rates[index])
# best_ms.append(momentums[index])
# best_widths.append(layer_widths[index])
# best_heights.append(layer_heights[index])
#
# print("Chosen Model: " + str(index))
# print("Final Loss: " + str(find_best_model[index]))
# print("Final Accuracy: " + str(histories[index].history['accuracy'][-1]))
# print("Final Learning Rate: " + str(learning_rates[index]))
# print("Final Momentum: " + str(momentums[index]))
# print("Layer Width: " + str(layer_widths[index]))
# print("Layer Height: " + str(layer_heights[index]))
# print("Trial: " + str(trial))
# trial += 1

# %%
score = best_model.evaluate(X_test, Y_test)
print('Test accuracy:', score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.9838 - accuracy: 0.2856
# Test accuracy: 0.2856000065803528

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(best_histories[idx].history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(best_histories[idx].history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
results = best_model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
predicted_classes = best_model.predict(X_test)

true_labels = np.argmax(Y_test,axis=1)

predicted_labels = np.argmax(predicted_classes,axis=1)

cm = confusion_matrix(true_labels, predicted_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

print("Accuracy: " + str(accuracy_score(true_labels, predicted_labels)))
print("Weighted Precision: " + str(precision_score(true_labels, predicted_labels, average='weighted')))
print("Weighted Recall: " + str(recall_score(true_labels, predicted_labels, average='weighted')))
print("Weighted F1 Score: " + str(f1_score(true_labels, predicted_labels, average='weighted')))
# Out:
# 313/313 [==============================] - 1s 4ms/step
# Accuracy: 0.7894
# Weighted Precision: 0.7933314405941213
# Weighted Recall: 0.7894
# Weighted F1 Score: 0.789827671440989

# %%
y_pred_ensemble = np.zeros((Y_test.shape))

#print(y_pred_ensemble.shape)

#count = 0
#for i in range(y_pred_ensemble.shape[0])
for model in models:
    y_pred_ensemble += model.predict(X_test)

y_pred_ensemble /= len(models)
# Out:
# 313/313 [==============================] - 1s 5ms/step
# 313/313 [==============================] - 1s 4ms/step
# 313/313 [==============================] - 1s 5ms/step
# 313/313 [==============================] - 2s 5ms/step

# %% [markdown]
# ### Extensions to the project
# 1. Alter parameters of layers (Number of perceptrons, more Convolution and pooling layers)
# 2. Preprocessing on the data (filter?)
# 3. Ensemble learning
# 4. Utilize Graphcore IPU

# %%
#print(y_pred_ensemble)
#print(np.argmax(y_pred_ensemble, axis=1))
ensemble_pred = np.argmax(y_pred_ensemble, axis=1)

# %%
#predicted_classes = ensemble_pred

true_labels = np.argmax(Y_test,axis=1)

predicted_labels = ensemble_pred

cm = confusion_matrix(true_labels, predicted_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

print("Accuracy: " + str(accuracy_score(true_labels, predicted_labels)))
print("Weighted Precision: " + str(precision_score(true_labels, predicted_labels, average='weighted')))
print("Weighted Recall: " + str(recall_score(true_labels, predicted_labels, average='weighted')))
print("Weighted F1 Score: " + str(f1_score(true_labels, predicted_labels, average='weighted')))
# Out:
# Accuracy: 0.8404
# Weighted Precision: 0.8431929486961726
# Weighted Recall: 0.8404
# Weighted F1 Score: 0.8405224380378155
